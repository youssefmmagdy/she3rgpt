# %%
import os
import requests
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import json

# Set device to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

batch_size = 64
block_size = 256
n_embd =  500
num_heads = 10
head_size = n_embd // num_heads
max_iters = 15000
eval_iters = 200
learning_rate = 3e-4
url = "/kaggle/input/datasets/yusufmagdy/poetry1/Arabic_Poetry_Dataset.csv"
num_layers = 12
dropout = 0.2
is_decoding = False
# Out:
# Using device: cuda

# %%
import pandas as pd

def get_data(path):
    dataset = pd.read_csv(path, on_bad_lines="skip")
    return dataset["poem_text"]

class Data():
    def __init__(self):
        self.batch_size = batch_size
        self.block_size = block_size
        dataset = get_data(url)

        # Join all poems into one string
        all_text = "\n".join(dataset.dropna().values)

        # Keep only Arabic letters (28 chars) and spaces/newlines
        ARABIC_LETTERS = set('ابتثجحخدذرزسشصضطظعغفقكلمنهويةىءأإآؤئ')
        all_text = "".join(c if c in ARABIC_LETTERS or c in (' ', '\n') else '' for c in all_text)
        print(f"number of characters is: {len(all_text)}")
        vocab = sorted(list(set(all_text)))
        self.vocab_size = len(vocab)
        print(f'distinct data length {len(vocab)}')

        stoi = {s: i for i, s in enumerate(vocab)}
        itos = {i: s for i, s in enumerate(vocab)}

        self.encode = lambda x: [stoi[i] for i in x]
        self.decode = lambda x: "".join([itos[i] for i in x])

        # OLD: Encode entire corpus as a plain python list (stays on CPU)
        # self.data = self.encode(all_text)

        # NEW: Encode entire corpus as a tensor on device (GPU if available)
        self.data = torch.tensor(self.encode(all_text), dtype=torch.long).to(device)

    def get_batch(self, split):
        n = int(0.9 * len(self.data))
        data = self.data[:n] if split == "train" else self.data[n:]

        rand = torch.randint(len(data) - self.block_size - 1, (self.batch_size,))

        # OLD: creates list of lists, then torch.tensor + .to(device) — slow CPU→GPU transfer each batch
        # X = [data[i:i+self.block_size] for i in rand]
        # Y = [data[i+1:i+self.block_size+1] for i in rand]
        # X, Y = torch.tensor(X).to(device), torch.tensor(Y).to(device)

        # NEW: data is already on device, torch.stack keeps it there — no CPU→GPU transfer
        X = torch.stack([data[i:i+self.block_size] for i in rand])
        Y = torch.stack([data[i+1:i+self.block_size+1] for i in rand])
        return X, Y

# %%
class FeedForward(nn.Module):
    def __init__(self):
        super().__init__()
        
        self.ffw = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout)
        )
    def forward(self, x):
        return self.ffw(x)

# %%
class Head(nn.Module):
    def __init__(self):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size)
        self.query = nn.Linear(n_embd, head_size)
        self.value = nn.Linear(n_embd, head_size)
        # self.tril = torch.tril(torch.ones(block_size, block_size)) # will not transfer it to the GPU
        self.register_buffer("tril", torch.tril(torch.ones(block_size, block_size))) # Without registering it, PyTorch will ignore it during device transfers
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B, T, C = x.shape # (batch_size, block_size, n_embd)
        k = self.key(x) # (B, T, head_size)
        q = self.query(x) # (B, T, head_size)

        # compute attention score ("affinities")
        wei = q @ k.transpose(-2, -1)* C ** -0.5 # (B, T, C) @ (B, C, T) -> (B, T, T) (batch_size, block_size, block_size)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float("-inf"))
        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)

        # perform the weighted aggregation of the values
        v = self.value(x)
        out = wei @ v # (B, T, head_size)
        return out

# %%
class MultiHead(nn.Module):
    def __init__(self):
        super().__init__()
        self.num_heads = num_heads
        self.heads = nn.ModuleList([Head() for _ in range(self.num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out)) # the projection back into the residual pathway
        return out

# %%
class Block(nn.Module):
    def __init__(self):
        super().__init__()
        self.ln1 = nn.LayerNorm(n_embd) # recently they use LayerNorm before not after
        self.heads = MultiHead()
        self.ln2 = nn.LayerNorm(n_embd)
        self.ffw = FeedForward()

    def forward(self, x):
        # x: (B, T, n_embd)
        x = x + self.heads(self.ln1(x)) # we fork off and do some communication and come back
        x = x + self.ffw(self.ln2(x))
        return x

# %%
class AttentionModel(nn.Module):
    def __init__(self, data):
        super().__init__()
        

        self.data = data
        
        self.embedding = nn.Embedding(self.data.vocab_size, n_embd) # (batch_size, block_size) -> (batch_size, block_size, n_embd)
        self.position_embedding = nn.Embedding(block_size, n_embd) # each position from 0 to block_size-1 will also get it's own embedding vector
        # self.blocks = nn.Sequential(
        #     Block(),
        #     Block(),
        #     Block()
        # )
        self.blocks = nn.Sequential(*[Block() for _ in range(num_layers)])
        self.ln = nn.LayerNorm(n_embd)
        self.linear = nn.Linear(n_embd, self.data.vocab_size)

    def forward(self, idx, targets=None):
        
        idx = idx[:, -block_size:] # because of pos-emb, we can not have more than block_size coming in, bec if idx more than block_size, pos-emb will run out of scope
        
        B, T = idx.shape # (batch_size, block_size)

        embd = self.embedding(idx) # (batch_size, block_size, n_embd) (4, 8, 32)
        pos_embd = self.position_embedding(torch.arange(T, device=device)) # (block_size, n_embd)
        x = embd + pos_embd # (batch_size, block_size, n_embd)
        
        x = self.blocks(x)
        x = self.ln(x)
        logits = self.linear(x)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)
        
        return logits, loss
    
    def generate(self, max_new_tokens):
        idx = torch.zeros((1, 1), dtype=torch.long, device=device)
        for _ in range(max_new_tokens):
            logits, loss = self(idx)
            logits = logits[:, -1, :] # (B, C) (4, 1, 65)
            probs = F.softmax(logits, dim=-1)
            
            idx_next = torch.multinomial(probs, 1)
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return self.data.decode(idx[0].tolist())
    
    @torch.no_grad() # letting PyTorch knows that there is no BP so no gradients will be calculated so memory efficient
    def estimate_loss(self, eval_iters):
        out = {}
        self.eval()
        for split in ['train', 'val']:
            # OLD: losses tensor on CPU
            # losses = torch.zeros(eval_iters)
            # NEW: losses tensor on device
            losses = torch.zeros(eval_iters, device=device)
            for k in range(eval_iters):
                X, Y = self.data.get_batch(split)
                logits, loss = self(X, Y)
                losses[k] = loss.item()
            out[split] = losses.mean()
        self.train()
        return out
    def train_model(self, learning_rate, max_iters):
        optimizer = torch.optim.AdamW(self.parameters(), lr=learning_rate)
        for i in range(max_iters):
            X, Y = self.data.get_batch("train")
            # forward
            logits, loss = self(X, Y)
            # backward
            optimizer.zero_grad(set_to_none=True)
            loss.backward()
            # update
            optimizer.step()
            if i % 100 == 0 or i == max_iters - 1:
                losses = self.estimate_loss(eval_iters)
                print(f"step {i}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

# %%
data = Data()

encoder = AttentionModel(data)
print('Encoder has ', sum(p.numel() for p in encoder.parameters())/1e6, 'M parameters')
encoder = encoder.to(device)
# Out:
# number of characters is: 39559252
# distinct data length 38
# Encoder has  36.245038 M parameters

# %%
encoder.train_model(learning_rate, max_iters)
print(encoder.generate(500))
# Out:
# step 0: train loss 3.9438, val loss 3.9590
# step 100: train loss 2.7525, val loss 2.7590
# step 200: train loss 2.7154, val loss 2.7219
# step 300: train loss 2.6461, val loss 2.6559
# step 400: train loss 2.4818, val loss 2.4894
# step 500: train loss 2.3993, val loss 2.4080
# step 600: train loss 2.3232, val loss 2.3300
# step 700: train loss 2.2542, val loss 2.2653
# step 800: train loss 2.1980, val loss 2.2077
# step 900: train loss 2.1487, val loss 2.1658
# step 1000: train loss 2.1173, val loss 2.1329
# step 1100: train loss 2.0778, val loss 2.0961
# step 1200: train loss 2.0502, val loss 2.0691
# step 1300: train loss 2.0257, val loss 2.0440
# step 1400: train loss 2.0026, val loss 2.0215
# step 1500: train loss 1.9880, val loss 2.0074
# step 1600: train loss 1.9669, val loss 1.9905
# step 1700: train loss 1.9549, val loss 1.9793
# step 1800: train loss 1.9401, val loss 1.9646
# step 1900: train loss 1.9293, val loss 1.9534
# step 2000: train loss 1.9154, val loss 1.9387
# step 2100: train loss 1.9047, val loss 1.9298
# step 2200: train loss 1.8988, val loss 1.9213
# step 2300: train loss 1.8898, val loss 1.9146
# step 2400: train loss 1.8786, val loss 1.9034
# step 2500: train loss 1.8715, val loss 1.8965
# step 2600: train loss 1.8655, val loss 1.8902
# step 2700: train loss 1.8568, val loss 1.8838
# step 2800: train loss 1.8486, val loss 1.8746
# step 2900: train loss 1.8428, val loss 1.8698
# step 3000: train loss 1.8360, val loss 1.8626
# step 3100: train loss 1.8272, val loss 1.8544
# step 3200: train loss 1.8238, val loss 1.8537
# step 3300: train loss 1.8169, val loss 1.8459
# step 3400: train loss 1.8100, val loss 1.8395
# step 3500: train loss 1.8058, val loss 1.8387
# step 3600: train loss 1.8000, val loss 1.8327
# step 3700: train loss 1.7930, val loss 1.8275
# step 3800: train loss 1.7887, val loss 1.8196
# step 3900: train loss 1.7819, val loss 1.8153
# step 4000: train loss 1.7778, val loss 1.8110
# step 4100: train loss 1.7729, val loss 1.8066
# step 4200: train loss 1.7657, val loss 1.8022
# step 4300: train loss 1.7631, val loss 1.7989
# step 4400: train loss 1.7609, val loss 1.7953
# step 4500: train loss 1.7558, val loss 1.7962
# step 4600: train loss 1.7522, val loss 1.7873
# step 4700: train loss 1.7485, val loss 1.7858
# step 4800: train loss 1.7412, val loss 1.7787
# step 4900: train loss 1.7374, val loss 1.7742
# step 5000: train loss 1.7348, val loss 1.7726
# step 5100: train loss 1.7291, val loss 1.7685
# step 5200: train loss 1.7239, val loss 1.7667
# step 5300: train loss 1.7202, val loss 1.7607
# step 5400: train loss 1.7158, val loss 1.7578
# step 5500: train loss 1.7135, val loss 1.7569
# step 5600: train loss 1.7095, val loss 1.7504
# step 5700: train loss 1.7049, val loss 1.7468
# step 5800: train loss 1.7015, val loss 1.7463
# step 5900: train loss 1.6979, val loss 1.7456
# step 6000: train loss 1.6937, val loss 1.7420
# step 6100: train loss 1.6886, val loss 1.7364
# step 6200: train loss 1.6886, val loss 1.7321
# step 6300: train loss 1.6855, val loss 1.7310
# step 6400: train loss 1.6777, val loss 1.7277
# step 6500: train loss 1.6748, val loss 1.7215
# step 6600: train loss 1.6697, val loss 1.7180
# step 6700: train loss 1.6661, val loss 1.7167
# step 6800: train loss 1.6628, val loss 1.7156
# step 6900: train loss 1.6638, val loss 1.7148
# step 7000: train loss 1.6589, val loss 1.7092
# step 7100: train loss 1.6559, val loss 1.7103
# step 7200: train loss 1.6494, val loss 1.7047
# step 7300: train loss 1.6499, val loss 1.6993
# step 7400: train loss 1.6480, val loss 1.7046
# step 7500: train loss 1.6438, val loss 1.6947
# step 7600: train loss 1.6361, val loss 1.6913
# step 7700: train loss 1.6334, val loss 1.6870
# step 7800: train loss 1.6354, val loss 1.6909
# step 7900: train loss 1.6257, val loss 1.6820
# step 8000: train loss 1.6252, val loss 1.6802
# step 8100: train loss 1.6207, val loss 1.6772
# step 8200: train loss 1.6200, val loss 1.6738
# step 8300: train loss 1.6140, val loss 1.6726
# step 8400: train loss 1.6150, val loss 1.6707
# step 8500: train loss 1.6109, val loss 1.6664
# step 8600: train loss 1.6115, val loss 1.6693
# step 8700: train loss 1.6098, val loss 1.6681
# step 8800: train loss 1.6077, val loss 1.6668
# step 8900: train loss 1.6030, val loss 1.6627
# step 9000: train loss 1.5983, val loss 1.6597
# step 9100: train loss 1.5941, val loss 1.6595
# step 9200: train loss 1.5937, val loss 1.6547
# step 9300: train loss 1.5902, val loss 1.6527
# step 9400: train loss 1.5888, val loss 1.6514
# step 9500: train loss 1.5857, val loss 1.6467
# step 9600: train loss 1.5809, val loss 1.6459
# step 9700: train loss 1.5831, val loss 1.6446
# step 9800: train loss 1.5769, val loss 1.6419
# step 9900: train loss 1.5762, val loss 1.6394
# step 10000: train loss 1.5742, val loss 1.6381
# step 10100: train loss 1.5738, val loss 1.6357
# step 10200: train loss 1.5706, val loss 1.6339
# step 10300: train loss 1.5693, val loss 1.6321
# step 10400: train loss 1.5680, val loss 1.6299
# step 10500: train loss 1.5644, val loss 1.6263
# step 10600: train loss 1.5634, val loss 1.6266
# step 10700: train loss 1.5590, val loss 1.6253
# step 10800: train loss 1.5608, val loss 1.6201
# step 10900: train loss 1.5540, val loss 1.6173
# step 11000: train loss 1.5537, val loss 1.6180
# step 11100: train loss 1.5536, val loss 1.6185
# step 11200: train loss 1.5559, val loss 1.6185
# step 11300: train loss 1.5501, val loss 1.6128
# step 11400: train loss 1.5494, val loss 1.6123
# step 11500: train loss 1.5457, val loss 1.6121
# step 11600: train loss 1.5445, val loss 1.6113
# step 11700: train loss 1.5434, val loss 1.6089
# step 11800: train loss 1.5400, val loss 1.6034
# step 11900: train loss 1.5381, val loss 1.6072
# step 12000: train loss 1.5367, val loss 1.6023
# step 12100: train loss 1.5342, val loss 1.6006
# step 12200: train loss 1.5334, val loss 1.5949
# step 12300: train loss 1.5330, val loss 1.6017
# step 12400: train loss 1.5336, val loss 1.5998
# step 12500: train loss 1.5310, val loss 1.5966
# step 12600: train loss 1.5312, val loss 1.5944
# step 12700: train loss 1.5299, val loss 1.5947
# step 12800: train loss 1.5258, val loss 1.5940
# step 12900: train loss 1.5266, val loss 1.5936
# step 13000: train loss 1.5244, val loss 1.5887
# step 13100: train loss 1.5226, val loss 1.5936
# step 13200: train loss 1.5223, val loss 1.5890
# step 13300: train loss 1.5220, val loss 1.5881
# step 13400: train loss 1.5174, val loss 1.5869
# step 13500: train loss 1.5179, val loss 1.5823
# step 13600: train loss 1.5177, val loss 1.5833
# step 13700: train loss 1.5143, val loss 1.5820
# step 13800: train loss 1.5117, val loss 1.5833
# step 13900: train loss 1.5121, val loss 1.5832
# step 14000: train loss 1.5114, val loss 1.5810
# step 14100: train loss 1.5066, val loss 1.5761
# step 14200: train loss 1.5068, val loss 1.5793
# step 14300: train loss 1.5090, val loss 1.5726
# step 14400: train loss 1.5069, val loss 1.5773
# step 14500: train loss 1.5061, val loss 1.5715
# step 14600: train loss 1.5011, val loss 1.5729
# step 14700: train loss 1.5021, val loss 1.5673
# step 14800: train loss 1.5003, val loss 1.5677
# step 14900: train loss 1.4982, val loss 1.5676
# step 14999: train loss 1.5009, val loss 1.5711
#
# وأعمى الله في البدر البياض
# وعنك ذكي العرف بالعروف
# ولا تسمع وإن جراك السماء
#
# قد خلقت من بلائه
# تمادحه بغتاته
# وكلما ركب الوثي
# به الجريض نحاته
# وهو على الشيء الهتا
# وعلى الفنن البلياته
# وآخروه قد أذا
# ع على الشباب قلاته
#
# هو المساء قد أقل الدقيق إذا عرت
# عين العذب في إسرائه الهبب
# تشكو الرياح ولم تفض الضحى علما
# تبيض نار به والتبر تنتسب
# أشري به العاش قل ليس ينقله
# وليس يغني عن الإنسان والنسب
# ثم استقل له واندب بنو رتب
# فقد عرفت الذي فارقت الزرد
# يا طاهر لما عاشت معاشته
# دفاعا يا معيشا لا أنا أبي حسب
# كإنه حاضر ال

# %%
print(encoder.generate(5000))
# Out:
# يطول عليه صفاح فضل ألفاظه
# فيا ليتي أعدي ليت لا تعدينه
# وجاز المتيم واجد شواها عن
# علي فيا حسني أبدا مفاخرا
# وعن كافي الأبرعين من العلا
# فلا تبعا طنبا ولا من هي
#
# منعت المنازل من أطلبا
# ومنك قر ومن آدمه
# تعزب بأن لا جائيا
# ومن أنت عبدك من يبلغه
#
# من بين مأوى ناعم ودعجل
# ترى جيلة بين الضلال تعرفه
# من بين مسه غلة وسلاسل
# ما غرق النسك والأسرة ينطفه
# إلا مواصل حسن كل مشرفه
# عجبا لقومك ورا لا أخ لدي
# فأرسلوا بك والإحسان ممرفه
# فما وجد أو ما ولدتك مولده
# إذ لا ينال عقول حوله حفه
# ما عشت ذل إليك فهي متخذ
# ولا هنالك عنها كان مجترمه
# لا أن أهجر أرضي الزمان بأعينه
# ولا أنل ما لداني الحال من هجم
# إلا اختيرت ندوبي بعض ما ليتها
# كم ساعة عش من عيش غيبها
# ولت خير من زيار قصرا وطنا
# إذ آل موسى يفيد الحادث التهمه
# خلى الصريخ لمن يزداد مال به ال
# لأواء من أنابيب المنى القدمه
# إن الحفائل أو من كاسف ورق
# خلع كمن لا يحس في وهما
# وإن محض نقي لم يشبه علا
# حسنته بزوال الهزل والزحم واهما
# فيا ليلة وافى لارفاد وإن
# قصرا وأغنى به الصبح المنير يممه
# بها اعتز من ولدت من نائله
# يبخس النائل الإكسير فيه مها
# جبل البسيطة يفخر النائل من
# بعد الجبين صفو من موامه
# قد زال في سوق الثناء بها حسنا
# وابشر بسنون المجد طلقا منامه
# طاه لأخلاق جدي عند غدرتها
# له بمسيىء من الزمان نعامه
# وطبعها فوق كفافيه الثرى
# مثار إلباس السرور نجامه
# وحق للعليا قد هدت أمري
# شتان فأوتي بعد قدر وضمنا
# وصح بين الصحف كان جليله
# قمر هفون الله فوق سهامه
# قدرها بدءا على فوراء أثر
# أبصرها في لجة العين سهامه
# ولكن كل قبال هذا فقابل ال
# فخر بأعداؤ العوالي سنامه
# بكأس مديحين العلى حين تمزد
# فظل فراشا من نداه نظامه
# سبى مسكين الفرع لم يجمع العلى
# ومن رجل قد عاد في أحلامه
# وخير الندى قد واصلت بمكارم
# عدا جوده والمكرمات خيامه
# متى شئت تكذى كأسه وتما له
# إذا كثر الساعين أو عن نعامه
# فلو عطفا لم يعهد الناس أنه
# صلاة لدي العارضين عزامه
# ولو أنه يفنى أبو يحسدا
# إذا كان غيظ الحي في حكمامه
# وتختال أعباء ديار كآبة
# محب تراه البين بعد غلامه
# به فرمته بعد عاد حسامه
# ودع عن بلاد الحييين في الهوى
# كراما ومن أخلاقه لا منامه
# وخلناهم خير الجزيل صدوره
# وليس لهم إلا الوشي قوامه
# ولست أعد النفس من حيث عاودت
# فنام لها من بعد ذاك ونامه
# دعا لو يفارقني المنون لم يسل
# بحسن ولا يحق القوام حزامه
# لئن قال وقف ما دعا لك حبه
# فهل لام بؤسا وهو بالأباعد حامه
# إليك من الآمال كذبن حولب
# إذا طلعت دلوية ومناهى
# فيا أيها الأيام تغلو إلى علا
# وجيشك في أعوام أذهابه قوامه
# حمى الحق أن يغشى على كل مفخر
# صديقك شكري في الزمان حناجه
# وهذا خراب حشوه ورجاؤه
# إذا افتخرت بالخيل بابن عليمه
# شكا يطمع المملوك منه جلاؤه
# بدا فلقت بالخيل نحو بروجه
# تباري وكل قائم بقواؤه
# وما أوجعت بالبعد منه طليقة
# وذال عليه نقعه وخراؤه
# وما مده نقع الإجازة مطمع
# ولا قدم المعروف فيمن نجاؤه
# لقد كنت فضلا صادقا فجلاءه
# فأصبحت للإعطاء بالصدق نعمة
# تغنيتها عني وحسن ذماؤه
# وإن شئت عن ورد النعامة يشتفي
# إليه بفخر لم تهنني شفاؤه
# فما وشيتي إلا امرؤ أجد الهوى
# حمى ياسرا ممن يمشي زراؤه
# بسلمي يمسي أسلما هو يعربا
# ويبقى لقد أصبحت منك زاؤه
# وعلمك مقصودا بغير هواته
# ومخلوق أن النبع أرض شفيته
# إذا بذلته فهو في ميراثه
# عزيز الزمان الهالك المتقلد
# إذا عن سوء من يفضل هولاؤه
# منحتجب قد كنت من دون ما تقى
# له شبع سلمان أحظ مهيمنا
# بأنعم مغراه السبيل إذ اهتدى
# أظن به أجلى تجدد داؤه
# له فضل مريم يرتحل عن شفى
# أظل قتيل البين كاد بسوأه
# حميم الملوك عند ملكي مسجد
# أحبتي نواه إن قلبي عتقه
# وأطمع بي إن كان في ذيل مجدة
# لو كان يخدعني لحقت مقصدا
# فلا أبلغ الأيام يسعدني يدي
# ولا أبلغ الأيام إلا أبو يد
# فلم أحتذره إن للأمر رحمة
# وحتى يراه في الزمان ممرضا
# والناس كان الجحفل الذات يركضي
# ترائب معشارا إلى ذات معشقي
# رأيت عن الأكوار ذما وجهدما
# نضوا عن جسمي لا تنوهوا وقد مضوا
# وللعداوة لولا عرسك ممسى
# وإن كان ملكا نحونا لم يفتقر
# بعد الجسوم إذا نشطته يسوغ لم يكن
# فإنك إن أنجز من هارب أبدي
# وذلك نابح بعد النواة بحبها
# أسير من الألاف منف من العرب
# وأشراس فرائس صدره تاج
# وما لظبا النشوان من فيض تاج
# أذلة نوأري الرجال لإعجاز
# عقتها من الملوات نائوس ميسر
# عليها بؤس دارس أو تمسك الحلب
# ومنها بأيديها نفوس حمام ب
# فأصبح صاد موثقا أو منسك
# يقول مقال الله فيها من الصبا
# وفاء بسهم الصب أبيض في صبا
# وفي الصبابة لو أنهم تاج
# قتلتم وما أسديتم قتل داهيا
# لمزحك ونقا من أذى كان هذا تصب
# كأن مريرات أبي بكر يحا
# ب المكر في وفرا لعطفك والكرب
# فدام رسول الله ذم فإن جرى
# وإن نفى بالسب عنكم وكرب
# جرائم قد صوحت منكم صلاتها
# وذات دهتنا في الزمان الترب
# بكى وأنت شؤبوبا ممن علمتني
# قد استشف يا أسماء آن لك العتب
# وكنت في فضل الذي كنت أحسن ال
# دهر وصار أبكي العلو لكن أبي
# وأنت مولاي مازال بينهم
# لكنك مشت في الذي قل لك الكذب
# وأنت في ضيم السرى وصوابه
# وما لهم والزاد بالمرتجى طلب
# ووالهم ذودي فإرثي آملا
# قد صار بيت العدل والفضل والعدب
# وما قواك إذا قال على شرف
# قد أنجزت عنك الكلام أين أبي
# وإن صدقت أبوابها ففضائلها
# فعصبة ووليك الشهب لم تفب
# ولي إلى انكرام داركم مصر
# يا موتها زادك قد آن فالسرب
# إجالة كشح كشح السيف نائمه
# فأصبح الحرب عن ألوانها ظرب
# تدنو أحال قصير العيش بعد قصر
# أحي يسوءك منها فهو ذي طنب
# إن يحجب الجن والإيماض نائله
# كما حديثا إلى دين من الذنب
# أحيا بما أنبتت في الدين ممتدحا
# أن تهزم البيت فيه في الورى العرب
# لعلها تترب الأرماح في قمر
# أعني بلحظ ودمع السحر وافي
# ما كل هند ولا إفراط في كلب
# يشفعه كالنجم والماء أو ذنب
# مثلين ما بيننا أقدارهم وشفت
# والليل عاجلهم من بين ذنب
# حوش رجالهم غارية سبقت
# محولها كل جن منهم الندب
# فكافأ الراح أو في سلبهم
# وكائن الله في قول وفي الجنب
# قد جنس الدين لما صح في بلدي
# فكنت أكره تربي بالفرض والولب
# حماهم في العلا بالوفر نال به
# لهم جديد وجد غيرها عرب
# ومن يئن علموا أن لا يراوعني
# فلا أقر ولا تربيحهم كلبوا
# ما أدب بينهم والوجد يرضعهم
# سواد عيني والن

# %%
encoder.train_model(learning_rate, max_iters)
# Out:
# step 0: train loss 1.5270, val loss 1.5926
# step 100: train loss 1.4979, val loss 1.5663
# step 200: train loss 1.4968, val loss 1.5675
# step 300: train loss 1.4942, val loss 1.5626
# step 400: train loss 1.4933, val loss 1.5678
# step 500: train loss 1.4941, val loss 1.5634
# step 600: train loss 1.4920, val loss 1.5611
# step 700: train loss 1.4911, val loss 1.5638
# step 800: train loss 1.4916, val loss 1.5621
# step 900: train loss 1.4887, val loss 1.5602
# step 1000: train loss 1.4874, val loss 1.5586
# step 1100: train loss 1.4836, val loss 1.5568
# step 1200: train loss 1.4853, val loss 1.5567
# step 1300: train loss 1.4841, val loss 1.5585
# step 1400: train loss 1.4872, val loss 1.5577
# step 1500: train loss 1.4832, val loss 1.5544
# step 1600: train loss 1.4818, val loss 1.5542
# step 1700: train loss 1.4809, val loss 1.5525
# step 1800: train loss 1.4793, val loss 1.5535
# step 1900: train loss 1.4774, val loss 1.5504
# step 2000: train loss 1.4747, val loss 1.5487
# step 2100: train loss 1.4745, val loss 1.5507
# step 2200: train loss 1.4750, val loss 1.5482
# step 2300: train loss 1.4738, val loss 1.5476
# step 2400: train loss 1.4750, val loss 1.5483
# step 2500: train loss 1.4717, val loss 1.5497
# step 2600: train loss 1.4717, val loss 1.5471
# step 2700: train loss 1.4709, val loss 1.5430
# step 2800: train loss 1.4722, val loss 1.5479
# step 2900: train loss 1.4685, val loss 1.5423
# step 3000: train loss 1.4680, val loss 1.5444
# step 3100: train loss 1.4661, val loss 1.5377
# step 3200: train loss 1.4678, val loss 1.5408
# step 3300: train loss 1.4671, val loss 1.5399
# step 3400: train loss 1.4669, val loss 1.5414
# step 3500: train loss 1.4627, val loss 1.5382
# step 3600: train loss 1.4634, val loss 1.5438
# step 3700: train loss 1.4622, val loss 1.5407
# step 3800: train loss 1.4602, val loss 1.5347
# step 3900: train loss 1.4578, val loss 1.5356
# step 4000: train loss 1.4614, val loss 1.5401
# step 4100: train loss 1.4586, val loss 1.5335
# step 4200: train loss 1.4574, val loss 1.5343
# step 4300: train loss 1.4595, val loss 1.5344
# step 4400: train loss 1.4560, val loss 1.5357
# step 4500: train loss 1.4540, val loss 1.5312
# step 4600: train loss 1.4570, val loss 1.5353
# step 4700: train loss 1.4537, val loss 1.5330
# step 4800: train loss 1.4550, val loss 1.5331
# step 4900: train loss 1.4524, val loss 1.5305
# step 5000: train loss 1.4520, val loss 1.5286
# step 5100: train loss 1.4482, val loss 1.5268
# step 5200: train loss 1.4509, val loss 1.5289
# step 5300: train loss 1.4504, val loss 1.5286
# step 5400: train loss 1.4486, val loss 1.5280
# step 5500: train loss 1.4500, val loss 1.5272
# step 5600: train loss 1.4442, val loss 1.5258
# step 5700: train loss 1.4487, val loss 1.5259
# step 5800: train loss 1.4492, val loss 1.5295
# step 5900: train loss 1.4448, val loss 1.5248
# step 6000: train loss 1.4468, val loss 1.5263
# step 6100: train loss 1.4415, val loss 1.5230
# step 6200: train loss 1.4431, val loss 1.5228
# step 6300: train loss 1.4392, val loss 1.5210
# step 6400: train loss 1.4406, val loss 1.5196
# step 6500: train loss 1.4412, val loss 1.5215
# step 6600: train loss 1.4402, val loss 1.5216
# step 6700: train loss 1.4403, val loss 1.5195
# step 6800: train loss 1.4370, val loss 1.5180
# step 6900: train loss 1.4405, val loss 1.5213
# step 7000: train loss 1.4397, val loss 1.5172
# step 7100: train loss 1.4386, val loss 1.5187
# step 7200: train loss 1.4384, val loss 1.5195
# step 7300: train loss 1.4370, val loss 1.5190
# step 7400: train loss 1.4347, val loss 1.5220
# step 7500: train loss 1.4334, val loss 1.5202
# step 7600: train loss 1.4322, val loss 1.5164
# step 7700: train loss 1.4322, val loss 1.5161
# step 7800: train loss 1.4317, val loss 1.5154
# step 7900: train loss 1.4299, val loss 1.5164
# step 8000: train loss 1.4293, val loss 1.5101
# step 8100: train loss 1.4304, val loss 1.5140
# step 8200: train loss 1.4293, val loss 1.5126
# step 8300: train loss 1.4269, val loss 1.5112
# step 8400: train loss 1.4286, val loss 1.5121
# step 8500: train loss 1.4258, val loss 1.5117
# step 8600: train loss 1.4257, val loss 1.5098
# step 8700: train loss 1.4254, val loss 1.5110
# step 8800: train loss 1.4247, val loss 1.5106
# step 8900: train loss 1.4236, val loss 1.5122
# step 9000: train loss 1.4237, val loss 1.5114
# step 9100: train loss 1.4213, val loss 1.5057
# step 9200: train loss 1.4247, val loss 1.5105
# step 9300: train loss 1.4246, val loss 1.5102
# step 9400: train loss 1.4222, val loss 1.5117
# step 9500: train loss 1.4221, val loss 1.5110
# step 9600: train loss 1.4205, val loss 1.5066
# step 9700: train loss 1.4188, val loss 1.5057
# step 9800: train loss 1.4178, val loss 1.5035
# step 9900: train loss 1.4172, val loss 1.5060
# step 10000: train loss 1.4196, val loss 1.5066
# step 10100: train loss 1.4180, val loss 1.5008
# step 10200: train loss 1.4179, val loss 1.5052
# step 10300: train loss 1.4143, val loss 1.5011
# step 10400: train loss 1.4148, val loss 1.5016
# step 10500: train loss 1.4146, val loss 1.5012
# step 10600: train loss 1.4115, val loss 1.5019
# step 10700: train loss 1.4121, val loss 1.5015
# step 10800: train loss 1.4131, val loss 1.4986
# step 10900: train loss 1.4137, val loss 1.5016
# step 11000: train loss 1.4107, val loss 1.4976
# step 11100: train loss 1.4123, val loss 1.4995
# step 11200: train loss 1.4119, val loss 1.4999
# step 11300: train loss 1.4118, val loss 1.4981
# step 11400: train loss 1.4110, val loss 1.4990
# step 11500: train loss 1.4082, val loss 1.4988
# step 11600: train loss 1.4094, val loss 1.4957
# step 11700: train loss 1.4074, val loss 1.4984
# step 11800: train loss 1.4058, val loss 1.4946
# step 11900: train loss 1.4072, val loss 1.4992
# step 12000: train loss 1.4052, val loss 1.4927
# step 12100: train loss 1.4065, val loss 1.4943
# step 12200: train loss 1.4075, val loss 1.4992
# step 12300: train loss 1.4067, val loss 1.4990
# step 12400: train loss 1.4048, val loss 1.4936
# step 12500: train loss 1.4040, val loss 1.4938
# step 12600: train loss 1.4019, val loss 1.4908
# step 12700: train loss 1.4022, val loss 1.4919
# step 12800: train loss 1.4020, val loss 1.4930
# step 12900: train loss 1.4003, val loss 1.4942
# step 13000: train loss 1.3986, val loss 1.4951
# step 13100: train loss 1.3993, val loss 1.4899
# step 13200: train loss 1.4006, val loss 1.4904
# step 13300: train loss 1.4009, val loss 1.4903
# step 13400: train loss 1.3990, val loss 1.4924
# step 13500: train loss 1.3992, val loss 1.4920
# step 13600: train loss 1.3969, val loss 1.4889
# step 13700: train loss 1.3952, val loss 1.4878
# step 13800: train loss 1.3974, val loss 1.4891
# step 13900: train loss 1.3960, val loss 1.4886
# step 14000: train loss 1.3955, val loss 1.4876
# step 14100: train loss 1.3946, val loss 1.4876
# step 14200: train loss 1.3934, val loss 1.4862
# step 14300: train loss 1.3931, val loss 1.4895
# step 14400: train loss 1.3938, val loss 1.4893
# step 14500: train loss 1.3904, val loss 1.4891
# step 14600: train loss 1.3920, val loss 1.4861
# step 14700: train loss 1.3900, val loss 1.4871
# step 14800: train loss 1.3914, val loss 1.4860
# step 14900: train loss 1.3916, val loss 1.4877
# step 14999: train loss 1.3904, val loss 1.4873

# %%
print(encoder.generate(5000))
# Out:
# بجيش لقاتله لا يرام
# وقد أشننت شقتيه الرمال
# يهاب فؤادك أمر همام
# فبم هاج يشكو وابتسم
# وقصرت الأسى والهجر ذنبى
# ألا لقيت الديار القفرة
# فأين الكمال أسود من أحد
# وخيرت للقبر والصحبه
# أجب لا تساعد عند الكربه
# ذوو الأدب الثاني عند الصحبه
# ومن لا ينام بعين القرب
# فإن فكم لا تفك في الكثر
# وإن لم يزد واقعا بالطمع
# فإنسانا علىلاه غنى
# بغ وانقطاعا لعمري بلمي
# ومن أشكر الله نعمى الوامي
# في حلى الحر سحب أثيل سهام
# وعن الله أنزه الكلام
# وأعين أفكار العيوب
# محاه الهدى أروس لا النور
# هذا زريق ذا المقاسي رضي
# نور مولانا فما يفلغ ظلط
# نظمت القم منك بالقرط
# فما أرى فيه هما عنا نبتسم
# ولا أردت خاطري بتهمهم
# مثل الكلام المطرف المختار
# وعدتني بنبواني جمال
# كممنع ما جاءنا يسخط بي
# قالوا عسى عن أن تغيب وأنت للصالح
# قالوا نلوم نلتقد بخار
# قد قلت لم تسمع ولم تقف مخيار قوام
# قلت اتئر وما سمعتم إذ قتل
# قالوا لقد قالوا غداة برى الكرى
# قالوا سحرت على الرضا والحذار
# وتم يا صحرتهم وانظر إلى ال
# بدر من الشعر مثل أحمر ضاحي
# قالوا من الفضل لكان به
# يشبع والجتم تسر شاكل
# قلت دت لك الفضل العدو الأبدا
# تؤم كرا على دعائ البرايا
# وسعدا عاضدا بعد حرف
# ثابت ظهور أعظم واضي
# صاحبت بهن عائن الفتى فان
# تراني حين اتقى فاقطع الأسى
# واصدق بذمك أمرا أبدا
# علما حلت الليالي الصنيعا
# مزبدا في كل ركن ربيعا
# أوت قدأ الدهر معنى وجيعا
# قبح الذائد أفعال شفيع
# يهرب في قبح الذي تدعى المنى
# وأبى الفصيحات السنان لفعله
# حتى شفيع الناس في الأمراس
# وقد أهان الركب بعد المراس
# لم يأت منهم قوله عنه قبله
# أن لم يكن يوم ذي الخلاس يرجى
# قتلا إلا إن ضللت بك الفعلا
# فأنت يا موسى جميع النفحات
# القلب رقيق وأفاد برائحا
# وكم ترى كالمطفئين بعاقد
# وكان يوم فيه إليك هو وصفا
# وإنما قد كان كعب في الثرى
# أن لنفحات الرياض الجبلا
# ورفع الملك لنحوك الروى
# عليك من كل الملوك القولا
# وخبر الرحمن قد زراء
# بالمؤمنين خبرا مقروء
# ملل قدرا في المعظوم فيه
# ونغمة الثغر الصنيع اليدين
# تسمع الدولة أعباء البريه
# وديمة الجود سطا فريده
# ثم يلاث من دماث خشع
# زهت الكماة فوق حد خضع
# تنفثهم للرعب فيه الغرب
# فطاب
# وطاب جاه منه إذ خفيه
# عن المألوس والشرفيه
# لله كم بعز أناس ذللوا
# خدمة علم أنتم المديور
# من ذدت الحزم وقد أعفيتم
# أقوالكم أقال لنو صورتم
# أن الأنام قرضكم في الوجود
# وللأنام عمت قديما طوبا
# وللذي شرفتم بالنجوم
# كم باح قبل لم يقصروا عميما
# ملأتم الفجر وكم ملأتم
# قد ألبس اللقطة حالا جليا
# وزمزم الغزو وشيكا أحزما
# وزمف الخمرة والعذول
# لهفي لقد ملأت فيها عنا
# وقال ليلى خيمة لتبلغا
# أرسلتها بعلام الجبهري
# أتظهري حورا وتكديرا معي
# بذلك المصعب والفتح الأدا
# لا تستفيق صولة الزمردا
# وتصرم العادة سفالحا
# فحالت القلب إلى الأعورا
# وكم تبني مهجة وتارة
# ضاق بتذكاري وما زويل
# وأكمل ال
# يقوى فلا يستبدل المعاندا
# ويا أبا لان على العلى
# قد اتخذ المنعة نعجا العلا
# ما نور الله يدير هدى
#
# وافى من البحر فقلت عاذره
# وكل جري حسير حائره
# وكبد المفرد باضطرابهه
# وجاءني زوجه وحاذره
# ودون جيش العجيب حاجره
# لا أذن الناس فيه حائرة
# اطعمها المنكب المقاصره
# أفعمه الحال فعش حائره
# فما عيوني ابيض معا حائره
# لا تنطق البحراء نفاحتها
# وإمرة عاد للحماء خاسره
# يدعو الغرور وابن غدارته
# للفلح مما يزيد غائره
# يبدأ فيه أغراضه عوا
# قوت الرجا والعدو آزره
# واليوم بيت الزمان أسعده
# وانظر اليعنفون آبره
# لا خير في الناس مثل ربكم
# خاطركم في اليمين ذاخره
# ودمتم للورى مواهبه
# في هزة والكمال جائره
#
# بقعود لليراع سؤالي وعز
# طال يا مستكين فيهضق الظلم
# ارتضينا به الجناب فصادت
# زبرتي حصيدة وحصن ضلال
# ضاحك في يمينه ونجال
# أقلع الناظرين بين التقى عن
# بر قلبي نقيصة وعلال
# بست اللحن للثلاثة أجرا
#  فمن بالبكاء جزعا وظلال
# هن في حمزة ومن فارس الحق
# أدرت جسم بالبؤس أي وقال
# عجل الصخر ناصروه وسطل
# وضاق الجد بالسؤال فوالي
# إنه ناصر يزين بحلم
# سابق ما يكاد بالتقى بعض زال
# ردت وردا ويذبل بحلق
# واشتفاء منه الخلاغة ما دام
# القرى والمقام ميزان الديار
# مستيحا ولو إذا ما ألحقتهن
# وارتمت سودت جسرة حاليه قط ضميزال
# رجل صعد وسمر وقوام
# حنش قد أتاك مستعجلا في تقيء
# وصدق أسماء وراج وكمرض
# ولئن أورثت معركة وقطعا
# لها القواضب أوفت دون عرض
# من بلد زيد فبكر أن يضحكها
# شر لجود لها على حد
# قيل على آباء أهل وصفاء
# يزل فانمل غاية الأقياء
# واذكر يرد منشرا أولائ
# وأكرم بأب عظيم علاء
# ودع نفوسا عنه وتزكو في الذي
# لم يعرف الإسراء والإسراء
# فشكرت ربك أحزن الأعداء
# ولك السلامة أنت ربك سار
# وكذا يلوح حرى مع الأحرار
# وشغلت في كل الخلال الأخيل
# ودام للأشياء في إطراق
# ونعمت عمته فكم وقصار
# وأتى على الباتى عمن ضمه
# سره سرانا بالبرية والوجود
# وأرى أحاديث الكرام وحسسا
# لم تدر والأظعان والأبواب
# والذنب وحدك ما طمي حديثك أيدي
# قلت لتلك الواء لا داء لمن رجوك
# فلأنعمني نارك التيجن لجام
# يا صاح يا لله بأ ختير لقى قمت
# في الخمر الأصفر حيا في العلقمه
# جميع ما قلبي سكنت لأرضه
# فالدهر إليك من الزمان جلابيب
#
# كأن الصديق المرء ظلمان ظنه
# أمام البرايا خفضة لم تكذب
# نطقت بفيحان الروامق من جوى
# من الترك حتى جاءني وتضرم
# وعجبت للقرب البعيد وباعدت
# فماذا على ندماني الربي يصرم
# وعدت فقال الوفد إن هو يسرها
# وإنهم صدق حراز عوق ومحرم
#
# هنيئا بوصي مغنم الميثاق
# فقلت له إني قريب فقابا
# ونفسي فيكم يا ربيع بذاتكم
# إن لم تكن غفلا عليه بسار
# فإن يكن المعذور ماء جفونكم
# فإنهما شرق قليل ثواء
# فكث عبور الشرب حين تباعدت
# وعطيك أسلاف القرين بداء
#
# وخذ بقلبي لأنكم أتعبوا
# فقال إن الذباب كالضريم
# واغدوت عند مقلتي الظعائن
# وابك الكماة شرب الفلاطم
# طاعت لبلدامة القتام
# مسافة يا أبا حمى مريمه
# وأرضعت في زيد محمل
# صنت خال فيكم وما لاحت
# غوى راحت بلألأ ووراد
# لاحت تر راجعا لا تركج
# ترى سلبت جاهها ابكار
# وإن بكت لحاظها الماء
# وذا الشجا برزت لي خمر
# وجسمها بالدم حد حسن
# قلت وقد بل في مساء ذكر
# كأنما الجسم نزحت اللبعه
# وطبقت في الفضوح قبرا ونزحا
# فمنه من السمير في سرح
# حتى إذا الليل أخطى مملك
# لتقمها من الجواش مرذ
# قاناه جباره ان قل قانا
# فأوقد

# %%
# Save model checkpoint
save_path = "arabic_poet_model.pth"
torch.save({
    'model_state_dict': encoder.state_dict(),
    'vocab_size': data.vocab_size,
    'hyperparams': {
        'block_size': block_size,
        'n_embd': n_embd,
        'num_heads': num_heads,
        'num_layers': num_layers,
        'dropout': dropout,
    }
}, save_path)
print(f"Model saved to {save_path}")
# Out:
# Model saved to arabic_poet_model.pth

# %%
torch.save(encoder.state_dict(), "/kaggle/working/arabic_poet_model.pth")
